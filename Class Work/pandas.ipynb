# %%
import pandas as pd
employee = {
    "id": [101,102,103],
    "name": ["Arjun","arun","mani"],
    "department": ["Data Analytics","programmer","visualization"],
    "skills": ["SQL", "Python", "Power BI"]}

data=pd.DataFrame(employee)
datas=data.loc[1]
datas
# Out:
# id                   102
# name                arun
# department    programmer
# skills            Python
# Name: 1, dtype: object

# %%
# Out:
# student name    Meena Nair
# Math                    76
# Science                 66
# English                 16
# History                 69
# Computer                69
# total                  296
# grade                    C
# result                Fail
# Name: 1, dtype: object

# %%
data["name"]
# Out:
# 0    Arjun
# 1     arun
# 2     mani
# Name: name, dtype: object

# %%
print(data.loc[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(data.loc[1])
#
# NameError: name 'data' is not defined

# %%
print(data.iloc[1])
# Out:
# id                   102
# name                arun
# department    programmer
# skills            Python
# Name: 1, dtype: object

# %%
"""condition greater than 90 peoples show
- slicing first 10 rows
-index auto assign in dataframe"""

# %%
import pandas as pd
data=pd.read_csv(r"C:/Users/tamil/Downloads/student_dataset_300.csv")


result=data[data["Math"]<90][["student name","Math"]]
#df=pd.DataFrame(data,index=["s1","s2","s3"]) #index name
result=result.head(10)# first 10
result.index=[f"s{i+1}" for i in range(len(result))] #index auto assign in dataframe

#results=result.loc["s1"]# choose the particular data
result
# Out:
#       student name  Math
# s1      Meena Nair    76
# s2      Pooja Iyer    87
# s3    Suresh Kumar    18
# s4     Meena Patel     1
# s5       Maya Nair     0
# s6     Kiran Kumar    29
# s7   Karthik Singh    51
# s8        Maya Rao    49
# s9      Ajay Singh    85
# s10         Ravi R    52

# %%
import pandas as pd
d=pd.read_csv(r"C:/Users/tamil/Downloads/student_dataset_300.csv")
sub=["Math","Science","English","History"]
failstu=d[(d[sub]<=35).any(axis=1)]
f=failstu.head()
f
# Out:
#    student name  Math  Science  English  History  Computer  total grade result
# 0      Maya Rao   100       20        4       86        68    278     C   Fail
# 1    Meena Nair    76       66       16       69        69    296     C   Fail
# 2    Pooja Iyer    87       21       61       95        40    304     B   Fail
# 3  Suresh Kumar    18        6       39        1        19     83     F   Fail
# 4   Meena Patel     1       47       58       68        35    209     D   Fail

# %%
avg_math = data["Math"].mean()
avg_math
# Out:
# np.float64(46.77)

# %%
import pandas as pd
d=pd.read_csv(r"C:/Users/tamil/Downloads/student_dataset_300.csv")
d.index=[f"m{i+1}" for i in range(len(d))]
data=d[d["result"]=="Fail"]
a=d[20:30]
a
# Out:
#       student name  Math  Science  English  History  Computer  total grade  \
# m21     Vikram Das     4       61       98       31        19    213     D
# m22     Nithin Rao    92       98       56        4        82    332     B
# m23     Ajay Kumar    59       49       11       46        65    230     D
# m24     Deepa Iyer    19        6       51       31        13    120     F
# m25     Arun Patel    84       27       60       86        39    296     C
# m26    Nithin Nair    89       76       22       67         8    262     C
# m27      Maya Nair    21        6       47       73         7    154     F
# m28      Maya Iyer    76       41       18       80        54    269     C
# m29  Suresh Sharma    50       85       84       54        86    359    B+
# m30       Nithin R    44       15        3       11        12     85     F
#
#     result
# m21   Fail
# m22   Fail
# m23   Fail
# m24   Fail
# m25   Fail
# m26   Fail
# m27   Fail
# m28   Fail
# m29   Pass
# m30   Fail

# %%
import pandas as pd
d=pd.read_csv(r"C:/Users/tamil/Downloads/student_dataset_300.csv")
d.index=[f"m{i+1}" for i in range(len(d))]
data=d[d["result"]=="Fail"]
a=d[20:30]
a
# Out:
#       student name  Math  Science  English  History  Computer  total grade  \
# m21     Vikram Das     4       61       98       31        19    213     D
# m22     Nithin Rao    92       98       56        4        82    332     B
# m23     Ajay Kumar    59       49       11       46        65    230     D
# m24     Deepa Iyer    19        6       51       31        13    120     F
# m25     Arun Patel    84       27       60       86        39    296     C
# m26    Nithin Nair    89       76       22       67         8    262     C
# m27      Maya Nair    21        6       47       73         7    154     F
# m28      Maya Iyer    76       41       18       80        54    269     C
# m29  Suresh Sharma    50       85       84       54        86    359    B+
# m30       Nithin R    44       15        3       11        12     85     F
#
#     result
# m21   Fail
# m22   Fail
# m23   Fail
# m24   Fail
# m25   Fail
# m26   Fail
# m27   Fail
# m28   Fail
# m29   Pass
# m30   Fail

# %%
fail_slice = data[20:30]   # Slices rows 20–29 of failing students
fail_slice.index = [f"f{i+1}" for i in range(len(fail_slice))]  # Optional custom indices
print(fail_slice)
# Out:
#       student name  Math  Science  English  History  Computer  total grade  \
# f1      Ajay Kumar    59       49       11       46        65    230     D
# f2      Deepa Iyer    19        6       51       31        13    120     F
# f3      Arun Patel    84       27       60       86        39    296     C
# f4     Nithin Nair    89       76       22       67         8    262     C
# f5       Maya Nair    21        6       47       73         7    154     F
# f6       Maya Iyer    76       41       18       80        54    269     C
# f7        Nithin R    44       15        3       11        12     85     F
# f8       Rahul Das    22       22       61       85        48    238     D
# f9   Karthik Gupta    15       28       95       52        98    288     C
# f10    Sneha Gupta    94       11       87       10        12    214     D
#
#     result
# f1    Fail
# f2    Fail
# f3    Fail
# f4    Fail
# f5    Fail
# f6    Fail
# f7    Fail
# f8    Fail
# f9    Fail
# f10   Fail

# %%
import pandas as pd
d=pd.read_csv(r"C:/Users/tamil/Downloads/student_dataset_300.csv")

data=d[d["result"]=="Fail"]
datafail=data[200:250]
datafail.index=[f"f{i+1}"for i in range(len(datafail))]
datafail
# Out:
#         student name  Math  Science  English  History  Computer  total grade  \
# f1        Nithin Rao    98       96       65       12        61    332     B
# f2       Divya Patel     2       10       87       46        31    176     D
# f3        Arun Singh    53       42       81       88        12    276     C
# f4       Vikram Iyer    22        3       48       43        95    211     D
# f5       Meena Gupta     4       51       96       43        24    218     D
# f6      Sneha Sharma    94       63        4       86        86    333     B
# f7   Aishwarya Gupta    94       51        2       42        26    215     D
# f8       Anjali Nair    83       83        1       23        27    217     D
# f9        Meena Nair    25       35        5       21        73    159     F
# f10     Anjali Gupta    33        0       46       70        29    178     D
# f11       Arun Gupta    22       62        6       95         7    192     D
# ...

# %%
import pandas as pd
d=pd.read_csv(r"C:/Users/tamil/Downloads/student_dataset_300.csv")

data=d[d["result"]=="Fail"]
#datafail=data[200:250]
data.index=[f"f{i+1}"for i in range(len(data))]
data
# Out:
#       student name  Math  Science  English  History  Computer  total grade  \
# f1        Maya Rao   100       20        4       86        68    278     C
# f2      Meena Nair    76       66       16       69        69    296     C
# f3      Pooja Iyer    87       21       61       95        40    304     B
# f4    Suresh Kumar    18        6       39        1        19     83     F
# f5     Meena Patel     1       47       58       68        35    209     D
# ...            ...   ...      ...      ...      ...       ...    ...   ...
# f261  Anitha Kumar    48       91       12       57         6    214     D
# f262     Priya Rao    79       58       31       71        17    256     C
# f263       Pooja R    10       16       98       74        66    264     C
# f264      Ajay Das    94        5       67       32         1    199     D
# f265    Meena Iyer    11       93       96       23        28    251     C
#
#      result
# f1     Fail
# f2     Fail
# f3     Fail
# f4     Fail
# ...
